# %%
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)

# %%
from urllib.request import Request
from bs4 import BeautifulSoup
import requests

# %%
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                         'Chrome/104.0.0.0 Safari/537.36'}


test = requests.get("https://www.musinsa.com/", timeout=5, headers=headers).text
print(test)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
#
#
#       <link rel="alternate" hreflang="en-hk" href="https://global.musinsa.com/hk/main"/>
#
#       <link rel="alternate" hreflang="en-tw" href="https://global.musinsa.com/tw/main"/>
#
#       <link rel="alternate" hreflang="ja-jp" href="https://global.musinsa.com/jp/main"/>
#
#       <link rel="alternate" hreflang="en-my" href="https://global.musinsa.com/my/main"/>
#
#       <link rel="alternate" hreflang="en-nz" href="https://global.musinsa.com/nz/main"/>
#
#       <link rel="alternate" hreflang="en-au" href="https://global.musinsa.com/au/main"/>
#
#       <link rel="alternate" hreflang="en-sg" href="https://global.musinsa.com/sg/main"/>
#
#       <link rel="alternate" hreflang="en-th" href="https://global.musinsa.com/th/main"/>
#
#       <link rel="alternate" hreflang="en-ph" href="https://global.musinsa.com/ph/main"/>
#
#       <link rel="alternate" hreflang="en-vn" href="https://global.musinsa.com/vn/main"/>
#
#       <link rel="alternate" hreflang="en-id" href="https://global.musinsa.com/id/main"/>
#
#       <link rel="alternate" hreflang="en-ca" href="https://global.musinsa.com/ca/main"/>
#
#       <link rel="alternate" hreflang="en-us" href="https://global.musinsa.com/us/main"/>
#
#       <link rel="alternate" hreflang="x-default" href="https://global.musinsa.com/HK/main"/>
#
#
#
#   <!-- Google Tag Manager -->
#   <script>
#       var dataLayer = dataLayer || [];
#       (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#               new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#           j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#           'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-5DMDPN4');
#   </script>
#   <!-- End Google Tag Manager -->
#
#
#
#     <script>
#         var DD_TRACING_DOMAIN = /https:\/\/*\.global\.musinsa\.com/
#         /*<![CDATA[*/
#         var DD_ENV = "prod";
#         var DD_SERVICE_VERSION = "202210171800";
#         (function(h,o,u,n,d) {
#             h=h[d]=h[d]||{q:[],onReady:function(c){h.q.push(c)}}
#             d=o.createElement(u);d.async=1;d.src=n
#             n=o.getElementsByTagName(u)[0];n.parentNode.insertBefore(d,n)
#         })(window,document,'script','https://www.datadoghq-browser-agent.com/datadog-rum-v4.js','DD_RUM')
#         DD_RUM.onReady(function() {
#             DD_RUM.init({
#                 clientToken: 'pubdc91632d92e51787c45790324bed7df0',
#                 applicationId: '5b5e1fc4-efdd-4645-bca0-34c3bd92b1f3',
#                 site: 'datadoghq.com',
#                 env: DD_ENV,
#                 service: 'global-musinsa-web',
#                 version: DD_SERVICE_VERSION,
#                 sampleRate: 3,
#                 premiumSampleRate: 0,
#                 trackInteractions: true,
#                 allowedTracingOrigins: [DD_TRACING_DOMAIN]
#             });
#             /*]]>*/
#         })
#     </script>
#
#
#     <script>
#         var agent = navigator.userAgent.toLowerCase();
#         if ((navigator.appName == 'Netscape' && agent.indexOf('trident') != -1) || agent.indexOf('msie') != -1) {
#             window.location.replace('/error/not-supported');
#         }
#     </script>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,minimum-scale=1,user-scalable=no,viewport-fit=cover">
#
#     <meta property="title" content="MUSINSA">
#     <meta property="description" content="Korea’s no.1 fashion store. Shop the latest trends from Seoul.">
#     <meta property="og:title" content="MUSINSA">
#     <meta property="og:image" content="https://static.msscdn.net/mfile_s01/fb/share_musinsa.png">
#     <meta property="og:description" content="Korea’s no.1 fashion store. Shop the latest trends from Seoul.">
#     <meta property="og:title" content="MUSINSA">
#     <meta property="og:image" content="https://static.msscdn.net/mfile_s01/fb/share_musinsa.png">
#     <meta property="og:description" content="Korea’s no.1 fashion store. Shop the latest trends from Seoul.">
#     <meta name="twitter:card" content="summary">
#     <meta name="twitter:title" content="MUSINSA">
#     <meta name="twitter:description" content="Korea’s no.1 fashion store. Shop the latest trends from Seoul.">
#     <meta name="twitter:image" content="https://static.msscdn.net/mfile_s01/fb/share_musinsa.png">
#
#     <link rel="canonical" href="https://global.musinsa.com/us/main" />
#     <link rel="alternate" hreflang="en-hk" href="https://global.musinsa.com/hk/main"/><link rel="alternate" hreflang="en-tw" href="https://global.musinsa.com/tw/main"/><link rel="alternate" hreflang="ja-jp" href="https://global.musinsa.com/jp/main"/><link rel="alternate" hreflang="en-my" href="https://global.musinsa.com/my/main"/><link rel="alternate" hreflang="en-nz" href="https://global.musinsa.com/nz/main"/><link rel="alternate" hreflang="en-au" href="https://global.musinsa.com/au/main"/><link rel="alternate" hreflang="en-sg" href="https://global.musinsa.com/sg/main"/><link rel="alternate" hreflang="en-th" href="https://global.musinsa.com/th/main"/><link rel="alternate" hreflang="en-ph" href="https://global.musinsa.com/ph/main"/><link rel="alternate" hreflang="en-vn" href="https://global.musinsa.com/vn/main"/><link rel="alternate" hreflang="en-id" href="https://global.musinsa.com/id/main"/><link rel="alternate" hreflang="en-ca" href="https://global.musinsa.com/ca/main"/><link rel="alternate" hreflang="en-us" href="https://global.musinsa.com/us/main"/><link rel="alternate" hreflang="x-default" href="https://global.musinsa.com/HK/main"/>
#
#     <link rel="shortcut icon" href="//image.msscdn.net/favicon_152.ico" type="image/x-icon"/>
#     <link rel="apple-touch-icon-precomposed" href="//image.msscdn.net/apple-touch-icon-precomposed_128.png" />
#     <link rel="apple-touch-icon-precomposed" href="//image.msscdn.net/apple-touch-icon-precomposed_152.png" sizes="152x152" />
#     <link rel="apple-touch-icon-precomposed" href="//image.msscdn.net/apple-touch-icon-precomposed_180.png" sizes="180x180" />
#
#
#     <meta name="google-site-verification" content="_qVBjO1-NXsct-1EueqGYJZZAdc4Gez3MRpbozAaMZk" />
#
#
#
#     <script>
#         var gtmObject = gtmObject || { pageId: '', country: '', currency: '' };
#         gtmObject.pageId = "\/main"
#         gtmObject.country = "us"
#         gtmObject.currency = ""
#     </script>
#
#
#     <script src="https://static.msscdn.net/static/global/appinterface/global-appinterface.js"></script>
#
#   <script>
#       var GLOBAL_MUSINSA = GLOBAL_MUSINSA || { initData: {} };
#       try {
net\/global\/images\/2022\/10\/18\/43e52988c73440a3839e2ea459e83c4c.jpg","landingUrl":"\/us\/promotion\/brand-typingmistake"},{"exhibitionId":null,"separateTitle1":"WAIKEI","separateTitle2":"Dolphin Universe","subTitle":null,"imageUrl":"https:\/\/image.msscdn.net\/global\/images\/2022\/10\/14\/4562969d09344703b9dd393d593402dd.jpg","landingUrl":"\/us\/brands\/waikei"}]},{"id":14,"type":"EXHIBITION","seq":4,"exhibitionId":132,"title":"NEW IN","subTitle":"","imageUrl":null,"landingUrl":"\/us\/new","displayType":"b","goodsList":[{"goodsNo":2741027,"goodsName":"Cashmere Double Breasted Coat (Beige)","imageUrl":"\/\/image.msscdn.net\/images\/goods_img\/20220825\/2741027\/2741027_2_500.jpg","brandName":"NOIRER","currency":"$","price":433,"normalPrice":433,"saleRate":0,"landingUrl":"\/us\/goods\/2741027"},{"goodsNo":2865343, ...
#       } catch (e) {
#           // do nothing
#       }
#   </script>
#
#
# </head>
# <body>
# <div class="container">
#
#   <div id="commonLayoutHeader"></div>
#
#
#
#     <div id="globalMain"></div>
#
#
#
#   <div id="commonLayoutFooter"></div>
#   <div id="commonLayoutMenubar"></div>
#
#   <script src="https://static.msscdn.net/static/global/common/1.0.0/global-common.js"></script>
#
#     <script src="https://image.msscdn.net/static/global/front/main/global-front-main.js"></script>
#     <script>
#         window.globalMss.render({
#             headerSelector: document.getElementById('commonLayoutHeader'),
#             footerSelector: document.getElementById('commonLayoutFooter'),
#             menubarSelector: document.getElementById('commonLayoutMenubar'),
#             desktop: {
#                 header: {
#                     use: true,
#                     titleBlind: false,
#                 },
#                 footer: {
#                     use: true,
#                 },
#                 menubar: {
#                     use: false,
#                     selected: 'home',
#                 },
#                 fab: {
#                     use: false,
#                 }
#             },
#             tablet: {
#                 header: {
#                     use: true,
#                     titleBlind: false,
#                     useBackButton: false,
#                     useSearchButton: true,
#                     useCartButton: true,
#                     useHomeButton: false,
#                     customTitleButtonClickEvent: (e) => {
#                         location.reload();
#                     },
#                 },
#                 footer: {
#                     use: true,
#                 },
#                 menubar: {
#                     use: true,
#                     selected: 'home',
#                 },
#                 fab: {
#                     use: true,
#                     useTopButton: true,
#                 }
#             },
#             mobile: {
#                 header: {
#                     use: true,
#                     titleBlind: false,
#                     useBackButton: false,
#                     useSearchButton: true,
#                     useCartButton: true,
#                     useHomeButton: false,
#                     customTitleButtonClickEvent: (e) => {
#                         location.reload();
#                     },
#                 },
#                 footer: {
#                     use: true,
#                 },
#                 menubar: {
#                     use: true,
#                     selected: 'home',
#                 },
#                 fab: {
#                     use: true,
#                     useTopButton: true,
#                 }
#             },
#             app: {
#                 header: {
#                     use: true,
#                     titleBlind: false,
#                     useBackButton: false,
#                     useSearchButton: true,
#                     useCartButton: true,
#                     useHomeButton: false,
#                     customTitleButtonClickEvent: (e) => {
#                         location.reload();
#                     },
#                 },
#                 footer: {
#                     use: true,
#                 },
#                 menubar: {
#                     use: true,
#                     selected: 'home',
#                 },
#                 fab: {
#                     use: true,
#                     useTopButton: true,
#                 }
#             },
#         });
#     </script>
#
# </div>
# </body>
# </html>
